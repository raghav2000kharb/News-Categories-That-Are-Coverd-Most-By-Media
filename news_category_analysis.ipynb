# %% [markdown]
# ### Reading the data frame into the jupyter note book, and importing required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
##iris_data = pd.read_json("News_Category_Dataset_v2.json", lines = True, encoding="utf8")
df= pd.read_json(open("/home/raghav/Desktop/News_Category_Dataset_v2.json", "r", encoding="utf8"),lines=True)
df
# Out:
#              category                                           headline  \
# 0               CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# ...               ...                                                ...
# 200848           TECH  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849         SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850         SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851         SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852         SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                  authors                                               link  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200853 entries, 0 to 200852
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   category           200853 non-null  object
#  1   headline           200853 non-null  object
#  2   authors            200853 non-null  object
#  3   link               200853 non-null  object
#  4   short_description  200853 non-null  object
#  5   date               200853 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.2+ MB

# %% [markdown]
# ### Creating a different dataframe for the combined categories

# %%
cats = df.groupby(['category']).count().reset_index()
cats
# Out:
#           category  headline  authors   link  short_description   date
# 0             ARTS      1509     1509   1509               1509   1509
# 1   ARTS & CULTURE      1339     1339   1339               1339   1339
# 2     BLACK VOICES      4528     4528   4528               4528   4528
# 3         BUSINESS      5937     5937   5937               5937   5937
# 4          COLLEGE      1144     1144   1144               1144   1144
# 5           COMEDY      5175     5175   5175               5175   5175
# 6            CRIME      3405     3405   3405               3405   3405
# 7   CULTURE & ARTS      1030     1030   1030               1030   1030
# 8          DIVORCE      3426     3426   3426               3426   3426
# 9        EDUCATION      1004     1004   1004               1004   1004
# 10   ENTERTAINMENT     16058    16058  16058              16058  16058
# 11     ENVIRONMENT      1323     1323   1323               1323   1323
# ...

# %% [markdown]
# ###  Graph for showing distribution of number of hradlines across varies news categories

# %%
plt.figure(figsize=(25,20))
plt.xlabel("Number of headlines in each News Category")
plt.ylabel("Categories")
plt.barh(cats["category"],cats["headline"], align="center",color="red")
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# ###  Extracting Year from the Date

# %%
df['year'] = df['date'].dt.year
df
# Out:
#              category                                           headline  \
# 0               CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# ...               ...                                                ...
# 200848           TECH  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849         SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850         SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851         SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852         SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                  authors                                               link  \
# ...

# %% [markdown]
# ### Number of Headlines in Different Categories over span of 6 Years (2012-18)

# %%
years = df.groupby(['category','year']).count().reset_index()
years
# Out:
#            category  year  headline  authors  link  short_description  date
# 0              ARTS  2014       801      801   801                801   801
# 1              ARTS  2015       618      618   618                618   618
# 2              ARTS  2016        87       87    87                 87    87
# 3              ARTS  2017         3        3     3                  3     3
# 4    ARTS & CULTURE  2015       207      207   207                207   207
# ..              ...   ...       ...      ...   ...                ...   ...
# 192      WORLD NEWS  2018       565      565   565                565   565
# 193       WORLDPOST  2014      1204     1204  1204               1204  1204
# 194       WORLDPOST  2015      1131     1131  1131               1131  1131
# 195       WORLDPOST  2016       226      226   226                226   226
# 196       WORLDPOST  2017        18       18    18                 18    18
#
# [197 rows x 7 columns]

# %% [markdown]
# ### 2012

# %%
year1= years[df['category'].notnull() & (years['year'] == 2012)]
year1
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2012")
plt.bar(year1["category"],year1["headline"], align="center",color="blue")
# Out:
# <BarContainer object of 21 artists>

# %% [markdown]
# ### 2013

# %%
year2= years[df['category'].notnull() & (years['year'] == 2013)]
year2
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2013")
plt.bar(cats["category"],cats["headline"], align="center",color="green")
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# ### 2014

# %%
year3= years[df['category'].notnull() & (years['year'] == 2014)]
year3
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2014")
plt.bar(cats["category"],cats["headline"], align="center",color="orange")
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# ### 2015

# %%
year4= years[df['category'].notnull() & (years['year'] == 2015)]
year4
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2015")
plt.bar(cats["category"],cats["headline"], align="center",color="black")
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# ### 2016

# %%
year5= years[df['category'].notnull() & (years['year'] == 2016)]
year5
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2016")
plt.bar(cats["category"],cats["headline"], align="center",color="magenta")
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# ### 2017

# %%
year6= years[df['category'].notnull() & (years['year'] == 2017)]
year6
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2017")
plt.bar(cats["category"],cats["headline"], align="center",color="yellow")
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# ### 2018

# %%
year7= years[df['category'].notnull() & (years['year'] == 2018)]
year7
plt.figure(figsize=(25,20))
plt.xlabel("Categories")
plt.ylabel("Number of Headlines of Different Categories in 2018")
plt.bar(cats["category"],cats["headline"], align="center",color="grey")
# Out:
# <BarContainer object of 41 artists>
